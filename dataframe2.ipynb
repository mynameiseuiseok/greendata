# %% [markdown]
# ## 운동(practice) 데이터 프레임 만들기

# %%
import pandas as pd

practice = pd.DataFrame({
    '날짜':[],
    '운동':[],
    '운동량':[]
})
practice
# Out:
# Empty DataFrame
# Columns: [날짜, 운동, 운동량]
# Index: []

# %%
# 데이터 추가, 변경 - loc()
practice.loc[0] = ['23-3-1', '달리기', 1]

practice
# Out:
#        날짜   운동  운동량
# 0  23-3-1  달리기    1

# %%
practice.loc[1] = ['23-3-1', '걷기', 1]
practice.loc[2] = ['23-3-2', '달리기', 1]
practice.loc[3] = ['23-3-2', '계단오르기', 1]
practice
# Out:
#        날짜     운동  운동량
# 0  23-3-1    달리기    1
# 1  23-3-1     걷기    1
# 2  23-3-2    달리기    1
# 3  23-3-2  계단오르기    1

# %%
practice.loc[4] = ['23-3-3', '걷기', 1.5]
practice.loc[5] = ['23-3-3', '달리기', 1]
practice
# Out:
#        날짜     운동  운동량
# 0  23-3-1    달리기  1.0
# 1  23-3-1     걷기  1.0
# 2  23-3-2    달리기  1.0
# 3  23-3-2  계단오르기  1.0
# 4  23-3-3     걷기  1.5
# 5  23-3-3    달리기  1.0

# %%
practice.loc[6] = ['23-3-3', '걷기', 1.5]
practice.loc[7] = ['23-3-3', '달리기', 1]
practice
# Out:
#        날짜     운동  운동량
# 0  23-3-1    달리기  1.0
# 1  23-3-1     걷기  1.0
# 2  23-3-2    달리기  1.0
# 3  23-3-2  계단오르기  1.0
# 4  23-3-3     걷기  1.5
# 5  23-3-3    달리기  1.0
# 6  23-3-3     걷기  1.5
# 7  23-3-3    달리기  1.0

# %%
practice.loc[6] = ['23-3-4', '걷기', 1.5]
practice.loc[7] = ['23-3-5', '달리기', 1]
practice.loc[8] = ['23-3-6', '걷기', 2.5]
practice.loc[9] = ['23-3-6', '달리기', 0.5]
practice
# Out:
#        날짜     운동  운동량
# 0  23-3-1    달리기  1.0
# 1  23-3-1     걷기  1.0
# 2  23-3-2    달리기  1.0
# 3  23-3-2  계단오르기  1.0
# 4  23-3-3     걷기  1.5
# 5  23-3-3    달리기  1.0
# 6  23-3-4     걷기  1.5
# 7  23-3-5    달리기  1.0
# 8  23-3-6     걷기  2.5
# 9  23-3-6    달리기  0.5

# %%
practice.pivot_table(index='운동')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4988\3481876503.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   practice.pivot_table(index='운동')
#          운동량
# 운동
# 걷기     1.625
# 계단오르기  1.000
# 달리기    0.900

# %%
practice.set_index('운동')
# Out:
#            날짜  운동량
# 운동
# 달리기    23-3-1  1.0
# 걷기     23-3-1  1.0
# 달리기    23-3-2  1.0
# 계단오르기  23-3-2  1.0
# 걷기     23-3-3  1.5
# 달리기    23-3-3  1.0
# 걷기     23-3-4  1.5
# 달리기    23-3-5  1.0
# 걷기     23-3-6  2.5
# 달리기    23-3-6  0.5

# %%
practice.pivot_table(index='운동', values='운동량', aggfunc='sum')
# Out:
#        운동량
# 운동
# 걷기     6.5
# 계단오르기  1.0
# 달리기    4.5

# %%
practice.pivot_table(index='운동', values='운동량') #평균
# Out:
#          운동량
# 운동
# 걷기     1.625
# 계단오르기  1.000
# 달리기    0.900

# %%
# to_csv() 파일 만들기
practice.to_csv('./datas/practice.csv')

# %%
practice = practice.set_index('날짜')  # 인덱스를 '날짜'로 설정

# %%
practice.to_csv('./datas/practice1.csv')

# %%
# 외부 파일 읽어오기 - pd.read_csv()
exercise = pd.read_csv('./datas/practice1.csv', index_col=0) #column = 0 '날짜'

# %%
exercise
# Out:
#            운동  운동량
# 날짜
# 23-3-1    달리기  1.0
# 23-3-1     걷기  1.0
# 23-3-2    달리기  1.0
# 23-3-2  계단오르기  1.0
# 23-3-3     걷기  1.5
# 23-3-3    달리기  1.0
# 23-3-4     걷기  1.5
# 23-3-5    달리기  1.0
# 23-3-6     걷기  2.5
# 23-3-6    달리기  0.5
