# %%
import csv

f = open('datas/age_2023.csv', 'r')
data = csv.reader(f)
next(data)

for row in data:
    if '대치1동' in row[0]:
        print(row)
f.close()
# Out:
# ['서울특별시 강남구 대치1동(1168060000)', '23,857', '23,857', '32', '53', '46', '64', '88', '146', '223', '217', '302', '376', '440', '512', '565', '548', '612', '643', '568', '507', '504', '437', '313', '289', '334', '251', '247', '217', '199', '172', '166', '132', '139', '128', '131', '100', '98', '106', '125', '129', '177', '227', '270', '359', '384', '525', '538', '597', '648', '636', '687', '636', '636', '625', '559', '513', '435', '327', '259', '290', '281', '244', '266', '231', '224', '217', '206', '208', '237', '199', '161', '180', '192', '123', '156', '132', '136', '132', '130', '80', '84', '66', '76', '55', '62', '51', '49', '34', '31', '22', '20', '17', '12', '13', '13', '10', '6', '3', '4', '3', '0', '3', '1', '11,965', '11,965', '19', '26', '25', '30', '50', '79', '103', '111', '169', '209', '236', '296', '307', '305', '357', '387', '298', '299', '288', '232', '166', '153', '163', '133', '127', '113', '107', '78', '84', '69', '78', '58', '60', '46', '46', '44', '42', '54', '60', '67', '95', '123', '126', '203', '221', '263', '279', '291', '314', '322', '326', '334', '294', '292', '252', '180', '150', '162', '163', '136', '131', '117', '102', '103', '102', '97', '102', '92', '82', '75', '93', '67', '82', '66', '73', '61', '55', '48', '48', '36', '44', '34', '31', '25', '19', '18', '18', '8', '10', '8', '5', '2', '6', '3', '1', '1', '0', '0', '0', '0', '0', '11,892', '11,892', '13', '27', '21', '34', '38', '67', '120', '106', '133', '167', '204', '216', '258', '243', '255', '256', '270', '208', '216', '205', '147', '136', '171', '118', '120', '104', '92', '94', '82', '63', '61', '70', '71', '54', '52', '62', '83', '75', '117', '160', '175', '236', '258', '322', '317', '334', '369', '345', '373', '314', '310', '291', '265', '221', '183', '147', '109', '128', '118', '108', '135', '114', '122', '114', '104', '111', '135', '107', '79', '105', '99', '56', '74', '66', '63', '71', '75', '32', '36', '30', '32', '21', '31', '26', '30', '16', '13', '14', '10', '9', '7', '11', '7', '7', '5', '2', '4', '3', '0', '3', '1']

# %% [markdown]
# ### 연령별 인구 시각화

# %%
import csv
import matplotlib.pyplot as plt

with open('./datas/age_2023.csv', 'r') as f:
    data = csv.reader(f)
    next(data)
    result = []  # 연령별 인구 저장할 리스트

    for row in data:
        if '불광제1동' in row[0]:
            for i in row[3:]:  # 3번 인덱스 ~ 104번(104-1) 인덱스까지
                result.append(int(i.replace(",", '')))  # 천단위 구분기호 제거

print(len(row[3:]))
# print(result)
plt.rc('font', family='Malgun Gothic')
plt.style.use("ggplot") # 격자 무늬 스타일
plt.title("연령별 인구 통계")
plt.plot(result, 'r')  # result - y축값
plt.xlabel('연령')
plt.ylabel('인구')
plt.show()
# Out:
# 101

# %%
import csv
import matplotlib.pyplot as plt

with open('./datas/age_2023.csv', 'r') as f:
    data = csv.reader(f)
    next(data)
    result = []  # 연령별 인구 저장할 리스트
    # 지역이름 입력받기
    name = input("지역의 이름(읍면동 단위)을 입력해 주세요: ")

    for row in data:
        if name in row[0]:
            for i in row[3:]:  # 3번 인덱스 ~ 104번(104-1) 인덱스까지
                result.append(int(i.replace(",", '')))  # 천단위 구분기호 제거

print(len(row[3:]))
# print(result)
plt.rc('font', family='Malgun Gothic')
plt.style.use("ggplot") # 격자 무늬 스타일
plt.title(name + "지역의 인구 구조")
# plt.plot(result, 'r')  # result - y축값
plt.bar(range(101), result) #x축-(0~100), y축 - result
plt.xlabel('연령')
plt.ylabel('인구')
plt.show()
# Out:
# 지역의 이름(읍면동 단위)을 입력해 주세요: 반포3동
# 101
